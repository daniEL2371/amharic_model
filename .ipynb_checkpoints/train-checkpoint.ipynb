# %%
# %run data_gen.ipynb
# %run models.ipynb
# Out:
# Using TensorFlow backend.

# %%
dg = DataGen(1)

# %%
n_batches = int(len(dg.vocab)/100)
batch_size = 100

# %%
gen = dg.gen(batch_size=batch_size, n_batches=n_batches, windows_size=4)

# %%
main_model, aux_model = conv_model(len(dg.vocab), 44)

# %%
history = main_model.fit_generator(gen, steps_per_epoch=n_batches, epochs=60)
# Out:
# Epoch 1/60
#  96/147 [==================>...........] - ETA: 6s - loss: 2.0297 - acc: 0.6007word  14703
# 147/147 [==============================] - 19s 129ms/step - loss: 2.0764 - acc: 0.5910
# Epoch 2/60
#  96/147 [==================>...........] - ETA: 6s - loss: 1.8788 - acc: 0.6147word  14703
# 147/147 [==============================] - 19s 128ms/step - loss: 1.9608 - acc: 0.6050
# Epoch 3/60
#  96/147 [==================>...........] - ETA: 6s - loss: 1.8212 - acc: 0.6282word  14703
# 147/147 [==============================] - 19s 128ms/step - loss: 1.9067 - acc: 0.6156
# Epoch 4/60
#  96/147 [==================>...........] - ETA: 6s - loss: 1.7763 - acc: 0.6361word  14703
# 147/147 [==============================] - 19s 128ms/step - loss: 1.8628 - acc: 0.6219
# Epoch 5/60
#  96/147 [==================>...........] - ETA: 6s - loss: 1.7468 - acc: 0.6403word  14703
# 147/147 [==============================] - 19s 128ms/step - loss: 1.8321 - acc: 0.6254
# Epoch 6/60
#  96/147 [==================>...........] - ETA: 6s - loss: 1.7192 - acc: 0.6451word  14703
# 147/147 [==============================] - 19s 129ms/step - loss: 1.8025 - acc: 0.6320
# Epoch 7/60
#  96/147 [==================>...........] - ETA: 6s - loss: 1.6925 - acc: 0.6482word  14703
# 147/147 [==============================] - 19s 129ms/step - loss: 1.7768 - acc: 0.6348
# Epoch 8/60
#  96/147 [==================>...........] - ETA: 7s - loss: 1.6697 - acc: 0.6510word  14703
# 147/147 [==============================] - 20s 135ms/step - loss: 1.7522 - acc: 0.6376
# Epoch 9/60
#  96/147 [==================>...........] - ETA: 6s - loss: 1.6311 - acc: 0.6606word  14703
# 147/147 [==============================] - 19s 128ms/step - loss: 1.7141 - acc: 0.6461
# Epoch 10/60
#  96/147 [==================>...........] - ETA: 6s - loss: 1.6141 - acc: 0.6623word  14703
# 147/147 [==============================] - 19s 129ms/step - loss: 1.6915 - acc: 0.6486
# Epoch 11/60
#  96/147 [==================>...........] - ETA: 6s - loss: 1.5886 - acc: 0.6660word  14703
# 147/147 [==============================] - 19s 130ms/step - loss: 1.6666 - acc: 0.6519
# Epoch 12/60
#  96/147 [==================>...........] - ETA: 6s - loss: 1.5650 - acc: 0.6725word  14703
# 147/147 [==============================] - 19s 126ms/step - loss: 1.6423 - acc: 0.6587
# Epoch 13/60
#  96/147 [==================>...........] - ETA: 6s - loss: 1.5456 - acc: 0.6704word  14703
# 147/147 [==============================] - 19s 126ms/step - loss: 1.6240 - acc: 0.6577
# Epoch 14/60
#  96/147 [==================>...........] - ETA: 6s - loss: 1.5197 - acc: 0.6727word  14703
# 147/147 [==============================] - 19s 126ms/step - loss: 1.5956 - acc: 0.6614
# Epoch 15/60
#  96/147 [==================>...........] - ETA: 6s - loss: 1.4974 - acc: 0.6776word  14703
# 147/147 [==============================] - 19s 126ms/step - loss: 1.5733 - acc: 0.6644
# Epoch 16/60
#  96/147 [==================>...........] - ETA: 6s - loss: 1.4872 - acc: 0.6772word  14703
# 147/147 [==============================] - 19s 126ms/step - loss: 1.5575 - acc: 0.6663
# Epoch 17/60
#  96/147 [==================>...........] - ETA: 6s - loss: 1.4598 - acc: 0.6846word  14703
# 147/147 [==============================] - 19s 127ms/step - loss: 1.5337 - acc: 0.6739
# Epoch 18/60
#  96/147 [==================>...........] - ETA: 6s - loss: 1.4437 - acc: 0.6852word  14703
# 147/147 [==============================] - 19s 126ms/step - loss: 1.5133 - acc: 0.6755
# Epoch 19/60
#  96/147 [==================>...........] - ETA: 6s - loss: 1.4306 - acc: 0.6865word  14703
# 147/147 [==============================] - 19s 126ms/step - loss: 1.4957 - acc: 0.6787
# Epoch 20/60
#  96/147 [==================>...........] - ETA: 6s - loss: 1.4146 - acc: 0.6902word  14703
# 147/147 [==============================] - 19s 127ms/step - loss: 1.4884 - acc: 0.6796
# Epoch 21/60
#  96/147 [==================>...........] - ETA: 6s - loss: 1.3913 - acc: 0.6974word  14703
# 147/147 [==============================] - 21s 141ms/step - loss: 1.4636 - acc: 0.6867
# Epoch 22/60
#  96/147 [==================>...........] - ETA: 7s - loss: 1.3834 - acc: 0.6949word  14703
# 147/147 [==============================] - 19s 132ms/step - loss: 1.4470 - acc: 0.6848
# Epoch 23/60
#  96/147 [==================>...........] - ETA: 6s - loss: 1.3876 - acc: 0.6906word  14703
# 147/147 [==============================] - 18s 120ms/step - loss: 1.4488 - acc: 0.6841
# Epoch 24/60
#  96/147 [==================>...........] - ETA: 6s - loss: 1.3750 - acc: 0.6952word  14703
# 147/147 [==============================] - 18s 120ms/step - loss: 1.4326 - acc: 0.6874
# Epoch 25/60
#  96/147 [==================>...........] - ETA: 6s - loss: 1.3432 - acc: 0.6979word  14703
# 147/147 [==============================] - 18s 120ms/step - loss: 1.4112 - acc: 0.6899
# Epoch 26/60
#  96/147 [==================>...........] - ETA: 6s - loss: 1.3331 - acc: 0.6985word  14703
# 147/147 [==============================] - 18s 120ms/step - loss: 1.3978 - acc: 0.6906
# Epoch 27/60
#  96/147 [==================>...........] - ETA: 6s - loss: 1.3279 - acc: 0.7001word  14703
# 147/147 [==============================] - 18s 120ms/step - loss: 1.3907 - acc: 0.6920
# Epoch 28/60
#  96/147 [==================>...........] - ETA: 6s - loss: 1.3162 - acc: 0.7047word  14703
# 147/147 [==============================] - 18s 120ms/step - loss: 1.3697 - acc: 0.6967
# Epoch 29/60
#  96/147 [==================>...........] - ETA: 6s - loss: 1.2937 - acc: 0.7110word  14703
# 147/147 [==============================] - 18s 120ms/step - loss: 1.3498 - acc: 0.7013
# Epoch 30/60
#  96/147 [==================>...........] - ETA: 6s - loss: 1.2823 - acc: 0.7125word  14703
# 147/147 [==============================] - 18s 120ms/step - loss: 1.3432 - acc: 0.7034
# Epoch 31/60
#  96/147 [==================>...........] - ETA: 6s - loss: 1.2745 - acc: 0.7111word  14703
# 147/147 [==============================] - 18s 120ms/step - loss: 1.3244 - acc: 0.7024
# Epoch 32/60
#  96/147 [==================>...........] - ETA: 6s - loss: 1.2733 - acc: 0.7114word  14703
# 147/147 [==============================] - 18s 120ms/step - loss: 1.3185 - acc: 0.7037
# Epoch 33/60
#  96/147 [==================>...........] - ETA: 7s - loss: 1.2651 - acc: 0.7062word  14703
# 147/147 [==============================] - 20s 138ms/step - loss: 1.3143 - acc: 0.6990
# Epoch 34/60
#  96/147 [==================>...........] - ETA: 6s - loss: 1.2342 - acc: 0.7146word  14703
# 147/147 [==============================] - 18s 120ms/step - loss: 1.2821 - acc: 0.7097
# Epoch 35/60
#  96/147 [==================>...........] - ETA: 6s - loss: 1.2173 - acc: 0.7234word  14703
# 147/147 [==============================] - 18s 120ms/step - loss: 1.2715 - acc: 0.7131
# Epoch 36/60
#  96/147 [==================>...........] - ETA: 6s - loss: 1.2139 - acc: 0.7236word  14703
# 147/147 [==============================] - 18s 120ms/step - loss: 1.2619 - acc: 0.7148
# Epoch 37/60
#  96/147 [==================>...........] - ETA: 6s - loss: 1.2029 - acc: 0.7219word  14703
# 147/147 [==============================] - 18s 120ms/step - loss: 1.2481 - acc: 0.7138
# Epoch 38/60
#  96/147 [==================>...........] - ETA: 6s - loss: 1.1961 - acc: 0.7229word  14703
# 147/147 [==============================] - 18s 120ms/step - loss: 1.2415 - acc: 0.7165
# Epoch 39/60
#  96/147 [==================>...........] - ETA: 6s - loss: 1.1707 - acc: 0.7313word  14703
# 147/147 [==============================] - 18s 120ms/step - loss: 1.2255 - acc: 0.7205
# Epoch 40/60
#  96/147 [==================>...........] - ETA: 6s - loss: 1.1660 - acc: 0.7301word  14703
# 147/147 [==============================] - 18s 120ms/step - loss: 1.2160 - acc: 0.7224
# Epoch 41/60
#  96/147 [==================>...........] - ETA: 6s - loss: 1.1618 - acc: 0.7296word  14703
# 147/147 [==============================] - 18s 121ms/step - loss: 1.2023 - acc: 0.7224
# Epoch 42/60
#  96/147 [==================>...........] - ETA: 7s - loss: 1.1412 - acc: 0.7352word  14703
# 147/147 [==============================] - 21s 143ms/step - loss: 1.1912 - acc: 0.7273
# Epoch 43/60
#  96/147 [==================>...........] - ETA: 7s - loss: 1.1417 - acc: 0.7327word  14703
# 147/147 [==============================] - 22s 147ms/step - loss: 1.1831 - acc: 0.7250
# Epoch 44/60
#  96/147 [==================>...........] - ETA: 6s - loss: 1.1160 - acc: 0.7353word  14703
# 147/147 [==============================] - 19s 128ms/step - loss: 1.1607 - acc: 0.7274
# Epoch 45/60
#  96/147 [==================>...........] - ETA: 5s - loss: 1.1123 - acc: 0.7420word  14703
# 147/147 [==============================] - 17s 114ms/step - loss: 1.1559 - acc: 0.7346
# Epoch 46/60
#  96/147 [==================>...........] - ETA: 6s - loss: 1.1109 - acc: 0.7353word  14703
# 147/147 [==============================] - 19s 131ms/step - loss: 1.1477 - acc: 0.7303
# Epoch 47/60
#  96/147 [==================>...........] - ETA: 6s - loss: 1.0940 - acc: 0.7393word  14703
# 147/147 [==============================] - 18s 125ms/step - loss: 1.1408 - acc: 0.7318
# Epoch 48/60
#  96/147 [==================>...........] - ETA: 6s - loss: 1.1174 - acc: 0.7311word  14703
# 147/147 [==============================] - 19s 126ms/step - loss: 1.1484 - acc: 0.7299
# Epoch 49/60
#  96/147 [==================>...........] - ETA: 6s - loss: 1.0971 - acc: 0.7363word  14703
# 147/147 [==============================] - 19s 126ms/step - loss: 1.1395 - acc: 0.7313
# Epoch 50/60
#  96/147 [==================>...........] - ETA: 6s - loss: 1.0833 - acc: 0.7395word  14703
# 147/147 [==============================] - 19s 126ms/step - loss: 1.1223 - acc: 0.7359
# Epoch 51/60
#  96/147 [==================>...........] - ETA: 6s - loss: 1.0628 - acc: 0.7453word  14703
# 147/147 [==============================] - 19s 126ms/step - loss: 1.1156 - acc: 0.7364
# Epoch 52/60
#  96/147 [==================>...........] - ETA: 6s - loss: 1.0572 - acc: 0.7446word  14703
# 147/147 [==============================] - 19s 126ms/step - loss: 1.1004 - acc: 0.7388
# Epoch 53/60
#  96/147 [==================>...........] - ETA: 6s - loss: 1.0250 - acc: 0.7512word  14703
# 147/147 [==============================] - 19s 126ms/step - loss: 1.0798 - acc: 0.7435
# Epoch 54/60
#  96/147 [==================>...........] - ETA: 6s - loss: 1.0230 - acc: 0.7545word  14703
# 147/147 [==============================] - 19s 126ms/step - loss: 1.0878 - acc: 0.7417
# Epoch 55/60
#  96/147 [==================>...........] - ETA: 6s - loss: 1.0014 - acc: 0.7576word  14703
# 147/147 [==============================] - 19s 126ms/step - loss: 1.0730 - acc: 0.7451
# Epoch 56/60
#  96/147 [==================>...........] - ETA: 6s - loss: 1.0010 - acc: 0.7615word  14703
# 147/147 [==============================] - 19s 127ms/step - loss: 1.0656 - acc: 0.7486
# Epoch 57/60
#  96/147 [==================>...........] - ETA: 6s - loss: 0.9863 - acc: 0.7632word  14703
# 147/147 [==============================] - 19s 126ms/step - loss: 1.0429 - acc: 0.7527
# Epoch 58/60
#  96/147 [==================>...........] - ETA: 6s - loss: 0.9908 - acc: 0.7587word  14703
# 147/147 [==============================] - 19s 126ms/step - loss: 1.0400 - acc: 0.7518
# Epoch 59/60
#  96/147 [==================>...........] - ETA: 6s - loss: 0.9696 - acc: 0.7626word  14703
# 147/147 [==============================] - 19s 127ms/step - loss: 1.0267 - acc: 0.7525
# Epoch 60/60
#  96/147 [==================>...........] - ETA: 6s - loss: 0.9663 - acc: 0.7650word  14703
# 147/147 [==============================] - 19s 126ms/step - loss: 1.0209 - acc: 0.7562

# %%
word_embeds = {}
for i in range(30):
    x, y = next(gen)
    embedding = aux_model.predict(x)
    words = dg.one_hot_decode(y)
    for j in range(len(y)):
        word_embeds[words[j]] = embedding[j]

# %%
def euclidean_dist(v, u):
    return np.sqrt(np.sum((v-u) ** 2))
def cosine(u, v):
    return u.dot(v)

# %%
def find_closest(word, embedding):
    min_distance = 1000
    close_words = []
    word_vec = embedding[word]
    for key in embedding.keys():
        vector = embedding[key]
        if euclidean_dist(vector, word_vec) < min_distance and not np.array_equal(vector, word_vec):
            min_distance = euclidean_dist(vector, word_vec)
            close_words.append(key)
    close_words.reverse()
    return close_words

# %%
s = ''
file = open('sim/sigmoid_wr_0pa44d_100_e50_b100_nb40.txt', 'w', encoding='utf-8')
for key in word_embeds:
    s += key + ' : '
    s += ' '.join(find_closest(key, word_embeds)[:5])
    s += '\n'
    file.write(s)
    s = ''

# %%
# u2_word = 'በእርሱ'
# v1 = word_embeds['በእንግሊዝ']
# v2 = word_embeds['ከእንግሊዝ']
# u1 = word_embeds[u2_word]
# v = v1 - v2 + u1
# v_norm = np.linalg.norm(v)
# m_u = -99999
# m_word = None
# for key in word_embeds.keys():
#     u2 = word_embeds[key]
#     d = v.dot(u2)/v_norm
#     if d > m_u and key != u2_word:
#         m_u = d
#         m_word = key
#         print(key)
    
    
# print(m_word)

# %%
# %matplotlib notebook
import random
import numpy as np
import matplotlib
# matplotlib.use('agg')
import matplotlib.pyplot as plt
import time

np.random.seed(200)

cho = [np.random.randint(3000) for k in range(100)] 
visualizeWords = [dg.words[i] for i in cho]

visualizeVecs = []
visWords = []
for j in range(len(visualizeWords)):
    key = visualizeWords[j]
    if key in word_embeds:
        visualizeVecs.append(word_embeds[key])
        visWords.append(key)
        
visualizeVecs = visualizeVecs[:50]
visualizeWords = visWords[:50]
temp = (visualizeVecs - np.mean(visualizeVecs, axis=0))
covariance = 1.0 / len(visualizeVecs) * temp.T.dot(temp)
U,S,V = np.linalg.svd(covariance)
coord = temp.dot(U[:,0:2])
print(coord.shape)
for i in range(len(visualizeWords)):
#     print(visualizeWords[i])
    plt.text(coord[i,0], coord[i,1], visualizeWords[i],
        bbox=dict(facecolor='green', alpha=0.1))

    
plt.rc('font', family='Abyssinica SIL')
plt.xlim((np.min(coord[:,0]), np.max(coord[:,0])))
plt.ylim((np.min(coord[:,1]), np.max(coord[:,1])))
plt.show()
# plt.savefig('images/q3_word_vectors.png')
cho = None
visWords = None
visualizeVecs = None
visualizeWords = None
plt = None
# Out:
# (32, 2)
# <img src="data:image/png;base64,..." width="640">
