# %%
# %matplotlib notebook
import numpy as np 
import matplotlib.pyplot as plt 
import numpy as np

# %%
am = open('data/news.txt', encoding='utf-8').read().split(' ')
en = open('data/text8.txt').read().split(' ')

# %%
def contains_digit(word):
    for i in range(10):
        if str(i) in word:
            return True
    return False

def count(words):
    counts = {}
    vocab = {}
    for word in words:
        if not contains_digit(word):
            if word not in counts:
                counts[word] = 0
                vocab[word] = len(vocab)
            counts[word] += 1
    return counts, vocab

def count_counts(counts, n_words):
    xs = []
    ys = []
    count_shares = {}
    for key in counts.keys():
        c = counts[key]
        if c not in count_shares:
            count_shares[c] = 0
        count_shares[c] += 1
    
    sorted_counts = sorted(count_shares.keys())
    for i in sorted_counts:
        x = i
        y = count_shares[i] / n_words
        xs.append(x)
        ys.append(y)
    return np.array(xs), np.array(ys)

# %%
n_am_words = len(am)
n_en_words = len(en)
am_counts, am_vocab = count(am)
en_counts, en_vocab = count(en)
am_x, am_y = count_counts(am_counts, n_am_words)
en_x, en_y = count_counts(en_counts, n_en_words)
am_vocab_size = len(am_counts.keys())

# %%
print("Amharic average frequency: ", (n_am_words/len(am_counts)))
print("Text average frequency: ", (n_en_words/len(en_counts)))
plt.plot(am_x[:10], am_y[:10]*100, label="amharic dataset")
plt.plot(en_x[:10], en_y[:10]*100, label="text8 dataset")
plt.xlabel("Frequency of words")
plt.ylabel("Percentage of counts")
plt.legend()
plt.show()
# Out:
# Amharic average frequency:  13.722629855186536
# Text average frequency:  66.9878789072502
# <img src="data:image/png;base64,..." width="640">

# %%
am_vocab_size
print(am_y[:10].sum())
print(en_y[:10].sum())
# Out:
# 0.06529548711863936
# 0.012304701006891535

# %%
m = 0
for word in am:
    if len(word) > 12:
        print(word)
# k = 0
# for word in am:
#     if len(word) > 11:
#         k += 1
# print(k)
# Out:
# አለመታተሙን/አለመውጣቱን
# የፓርቲዎቹ/የድርጅቶቹ
# ተንዘርጥጣእንደተቆዘረች
# ከነማ23/05/20078
# ከነማ23/05/200710
# ከመከላከያ28/05/20078
# ከደደቢት28/05/200710
# ከኤሌክትሪክ30/05/200710
# ድቻ30/05/20078
# አስፈጻሚየኢንተርፕሩነርሺፕ
# የምንገዳደልም/የምንገድልም
# የሌቫንት/የሻም/የሦሪያ
# ጠባቂዎችተከላካዮችአሰግድ
# እግዚአብሔርኢትዮጵያችን
# የሶሻሊዝም/ኮሙዩኒዝም
# እንደየአስፈላጊነታቸው
# ያስተላለፉት/ያሰራጩት
# ሲሰብሩስኮትላንዳውያኑ
# ኢንስቲትዩትውይይትዝግጅት
# ዓመታትበ1920ዎቹየደአማት
# የማይጨንቀንበማስመሰል
# እንሰማቸዋለን/እናያቸዋለን
# የፍ/ሥ/ሥ/ሕ/ቁ/445ን
# አስተዳዳሪበሽብርተኝነት
# የማይጨንቀንበማስመሰል
# ልጃችሁእንዳይታዘባችሁ
# ለኢንዱስትራላይዜሽንና
# የመክፈል/የማስተላለፍ
# ያደራጀሁት/ያጠናከርኩት
# እንግሊዛዊትእንግሊዛዊቷ
# ስለመንፈሳዊነትመንፈሳዊነት
# ምረቃበዩኒቨርሲቲዎችና
# ተፈረደባቸውየኢትዮጵያ
# የሚያስፈልግዎሽንኩርትዘይትበርበሬየወጥ
# 3450ናይጄሪያ18250
# የጠባብነት/የትምክህት
# የትምክህተኞች/የጠባቦች
# ክርስትናን/እስልምናን
# የሚመረጠውን/የምትመረጠውን
# ወልደየስበሽብርተኝነት
# አስተዳደርበሽብርተኝነት
# ኢ/እ/ኳ/ዳ/ታ/ሙ/ማ/58/06
# ኢ/ዳ/ታ/ሙ/ማ/59/07
# ዕቃዎችአዘገጃጀትደብረወርቅ
# የማይታወቅበትምንድነው
# የኢትዮጵያችን/ሕዝባችን
# እቀይረዋለሁየትናንቴን
# በየስብሰባ/በየኮንፈረንሱ
# የሚያስፈልግዎፓስታሽንኩርትዘይትቲማቲም/የቲማቲም
# የለኝምአያሳስበኝምየሆነው
# እንደፍጥረቴተቀብዬሻለሁ
# ካስቸገረአንተናኔአንቺናኔሳንሞት
# የሚጠቀሙበት/የሚጥሱት
# በርበሬዱቄትአዘገጃጀት
# አ/አ/አመልማቢ/81/2145/06
# ቁ/አ/አሥ/01/26/281
# የሚተጫጩበት/የሚመራረጡበት
# ለማስደንበሪያበአምስተኛው
# ቁንዶበርበሬአዘገጃጀት
# በእግዚአብሔርአገራችን
# ለመቁረጥስኮትላንዳዊው
# ያልተጻፈውን/በመስመር
# አስተዋጽኦዋቸው/የድርጅቱንም
# ሶርያዊትአይኤስአይኤስ
# ዩኒታሪያኒዝምሁላችንም
# ኮንፉሺያኒዝምየመልካም
# ዞሮአስትሬይኒዝምአንተን
# ልቡናህሲያውቀውየሕይወቱ
# አምላክእንዲሆነውምክንያቱምይኼ
# አፈጻጸሙያለማስጠንቀቂያ
# ዕቃዎችአዘገጃጀትደብረወርቅ
# ኢንዱስትሪያላይዜሽንን
# የሚሾሙት/የሚመደቡትም
# ከባስለሰሪሪሪበለሥልጣንም
# እንዳነበብኩትየመጀመርያ
# ከባስለሰሪሪሪበለሥልጣንም
# የዲሞዎች/የአናርኪቶች
# ሕዝቦች/የትምክህተኞች/የገበያ
# የመወያየት/የመከራከር
# አከፋፈልእንደሚታወቀው
# የተያዘበት/የታገደበት
# ለሚጓዙባለመኝታባለመኝታ
# ክፍልከላይከመሀልበታችከላይበታችለቡ0
# 00ብርብርብርብርብርብርአዳማ996891125137171182ድሬዳዋ446308410564615769821አልሳቤህ66545961284191811471224ነጋድ729503671922100612581341
# አይችልምቴርሞዳይናሚክስን
# እንከራያለን/እንገዛለን
# የአቋራጭ/ያልተለፋበት
# የማስተማርን/የቁጥጥር
# ተማሪዎቻቸው/ተመካሪዎቻቸው
# ተጠያቂነትስለማሰቃየት
# 01/1/9/11/33/3
# ኢዲክ9/ኢጠ/1/662
# እንቅስቃሴስለአገራችን
# ስኮትላንዳዊበአውሮፓውያኑ
# የመበስበስ/የመሰንጠቅ
# ተመሥርቶባቸዋልየመላው
# ችግሮችበዩኒቨርሲቲዎች
# በተቀመጠው/በተቀመጡት
# አረቦችንምታስተናግዳለች
# አቅዷልበፕራይቬታይዜሽንና
# አትሌትጊዜከተማዓመትጥሩነሽ
# 15ኦስሎ29/09/2000መሠረት
# 88ስቶክሆልም15/11/2000አልማዝ
# 32ሻንጋይ09/09/2007መሠረት
# 63ኦስሎ08/10/1999ገንዘቤ
# 76ዩጂን22/09/2007ቪቪያን
# 87ስቶክሆልም22/11/2003
# ስለዴሞክራሲያዊነታቸው
# ዲሞክራሲያዊነትበእርግጥም
# የቀረቡትበሽብርተኝነት
# ስላለመኖሩም/በእርግጠኝነት
# ወንድማማችነትከስድሰት
# በወ/መ/ሥ/ሥ/ቁ/141
# ከማለማመድ/ከማሠልጠን
# እንደማስደንበሪያየግል
# ለሚመሩት/ለሚያስተዳድሩት/ለሚገዙት
# የተዋረድኩትእንድትኖር
# ከማኅበረሰብ/ቡድን/ብሔረሰብ
# ቁንዶበርበሬአዘገጃጀት
# ፍቅርስለወዘወዘኝላሞላላት
# ደክሜብትቀይርልኝከፋፍታ
# በርበሬአዘገጃጀትጆርዳና
# አያላውሳትምመቀመጫውን
# እንደሚያስሰውፍቅርሽን
# ቁንዶበርበሬአዘገጃጀት
# አካባቢያችንንየሚበክሉ
# ብታነፃፅሩታገኙታላችሁ
# አልተፈጠረችምየገንዘብ
# ቅቤአዘገጃጀትከስድስት
# ተሸልመዋልየኤሚሪባስክ
# ቁንዶበርበሬአዘገጃጀት
# መቆራረጥእንደማንኛውም
# ተሳትፎበት/ተወያይቶበት
# አልተቀበለውምየፌዴራል
# ተሰጠላቸውበሽብርተኝነት
# የገለበጡትን/ያወረዱትን
# ኮርፖሬሽኖች/ኢንዱስትሪዎች
# ዲኢንዱስትሪያላይዜሽን
# የወ/መ/ሥ/ሥ/ሕ/ቁጥር
# ተቃዋሚዎች/ተፎካካሪዎች
# የአፍሪካውያን/ኢትዮጵያውያን
# ቆሟልእየተሳቀለባንደኛው
# ከኢንዱስትሪያላይዜሽን
# ኢንዱስትሪያላይዜሽንና
# ጉዳተኞችበፖለቲካባለፉት
# የተመዝጋቢው/የደረሰው
# በማያውቀው/ባልተቀበለው
# ያስፈልገዋልየኢትዮጵያ
# አልተሰጠበትምየ2010
# የሚያዘነብሉትእየጠገንካቸው
# ትሰዳለህበማስመለሳቸው
# 1000239345488
# ገ/እግዚአብሔርአንዲትን
# ኦቨርኮሜርሽያላይዜሽን
# ሚኒስትርአስመሳይነትና
# ማጠቃለያየትራንስፖርት
# ጦማሪያንበተጠረጠሩበት
# አፈጻጸሙከማኑፋክቸሪንግ
# ታልሚያለሽናጐረቤቶቻችን
# ማውለብለብወደተባበሩት
# በየስብሰባ/በየኮንፍራንሱ
# በዴሞክራሲየምንዳኝበት
# ኢንስቲትዩትእንቁጣጣሽ
# ጠፋፈረችእንዲበርድላቸው
# የኢትዮ/ገ/ጉ/ባ/ዐ/ሕግ
# የኖሩባቸው/ያደጉባቸው
# መገልመጥ/ማብጠልጠልና
# የሚቀርብላቸው/ከተፎካካሪ
# ከማሰቀል/ከማስጨብጨብ
# ዘመንአቆጣጠርበኢትዮጵያ
# ከአስተዳዳሪዎች/ሹሞች
# አመራረጣችን/አሿሿማችን
# መንደርተኝነትን/የሠፈር
# በተመደበበት/በተሰየመበት
# እቀይረዋለሁየትናንቴን
# አደረጃጀቶችበመደራጀት
# ኢንቨስትመንትየኢንሹራንስ
# የዲሞዎች/የአናርኪስቶች
# ሕዝቦች/የትምክተኞች/የገበያ
# የመወያየት/የመከራከር
# እንደየግለሰቡ/እንደየድርጅቱ
# ታስቀምጣለችበፖለቲካና
# ወይዘሮመድኃኒትአዳነየተባለችውእመቤትረጅምናወፍራምስለነበረችባለቤቷአቶበላይሲኞሬ
# የተባለውበጣልያንዘመንዕንቁላልከሚኖርበትየገጠርመንደርየጣልያንጦርወደሰፈረበትካምፕእየወሰደ
# እያለበልጅነቱለጣሊያኖችይሸጥስለነበርነው
# ሲልቤተሰቦቹስለሰሙትከዚያጊዜጀምሮበላይተሰማመባሉቀርቶበላይሲኞሬተባለ
# ከዕለታትበአንዱበላይካምቦ
# ቅምጥአለቺውመባልንባለቤቱወ/ሮመድኃኒትሰምታናአጣርታስለደረሰችበትበቀንምድርበርዘግታበትናከመደብላይአጋድማስትደበድበውናስታሸው
# በማለትስትደበድበውጎረቤትተሰበሰበናበሩንከፍቶሲገባ
# በሚልሰውእንዳያመነጥጣት
# /ስሟንበክፉእንዳያነሳው/
# ከላዩላይተነስታከሥርትሆናለች
# በላይሲኞሬምአጥቂበመምሰልከላይዋላይሆኖእንደዶሮሲንፈራፈርአንድገላጋይይይዘዋል
# ሲኞሬምየልቡንሳያደርስገላጋይበመሃልበመግባቱተናድዶ
# አያዳምጤተወኝማየአሁንግልብጥነኝ
# ቅኔእናቅኔያዊጨዋታለትዝታ
# አፍሮኤስያዊ/አፍሮኤሽያቲክ
# አለመሟላትየባለአክሲዮኖች
# ቀደምኢትዮጵያውያንነገሥታትቀይባሕርንተሻግረውየመንንናሌሎችንምየዐረብአገራትይገዙናያስተዳድሩነበር
# በዚያዘመንየነበረንጉሥከባሕርማዶዘመቻሲመለስ
# በረሃለበረሃየተንከራተትነውአንሶ
# ምንምቢሆንየንጉሥትዕዛዝነው
# በማለትትንሽትንሽአፈርበየጨርቁጫፍቋጠረ
# ከቀናትበኋላባሕሩንተሻግረውየኢትዮጵያመሬትሲረግጡንጉሡ
# የያዛችሁትንአፈርአውጡ
# ባላቸውጊዜየቋጠሩትአፈርወርቅሆኖተገኘ
# በዚህምምክንያትማንምደስተኛሊሆንአልቻለም
# ሁለቱምወገኖችእኩልአዝነዋል
# አፈርብንጨምርበትምንነበር
# ምነውየእነሱንያህልእንኳንበያዝን
# በዚህምአጋጣሚመነሻነትእንዲህሲባልይኖራል
# ዘአኀዙወርቀወዘኢአኀዙ
# ወርቅየያዙትምያልያዙትምሁለቱምበአንድነትአዘኑ
# የሚለውምሳሌያዊአነጋገርምመነሻውይህመሆኑአይጠረጠርም
# ብዙገበሬዎችከሚያደርጉትሁሉየተለየፈጠራናችሎታምነበራቸው
# በአህዮቻቸውከአውድማእህልጭነውወደቤትሲወስዱአህዮቹከብዷቸውከነጭነቱመሬትሲተኙበዱላይደበድቧቸዋል
# እኚህገበሬግንአይደበድቡም
# ገናማለዳከቤታቸውሲወጡለአህያውማባቢያየሚሆንካሮትበኪሳቸውይዘውይሄዳሉ
# የጫኑትአህያመሬትሲተኛረጅምእንጨትከጋማውጋርያስሩናከእንጨቱጫፍካሮቷንጨምረውያስራሉ
# በዚህጊዜአህያውካሮቷንሲያይለመብላትይነሳል
# በዚህሁኔታበቀላሉቤትይደርሳል
# አሁንምገበሬውካሮቷንአንሥተውበኪሳቸውያደርጋሉ
# እባክዎአባቴከርስዎጋርብነጋገርእወዳለሁና
# አንዳንድነገርእንድጠይቅዎፈቃድዎይሁንአልኳቸው
# የንግግርብዛትበአህያአይጫንም
# ዛሬበሥራከሚገለጸውበንግግርብቻየሚተረከውእየበዛንግግርናሥራሳይገናኙይኖራሉ
# በእኔዕድሜካሉጠይቆመማርበተጠላበትጊዜእንዴትአንተእኔንበማነጋገርበዕድሜህየማታውቀውንለማወቅፈለግህ
# ልጄበዕድሜዬያየሁትንናየተማርሁትንብነግርህበወደድሁ
# ይሁንናየትምየትብትሄድንግግርብቻትሰማለህ
# ንግግርካልተሠራበትበኖይቀራል
# ሰውንሰውበንግግርብቻያሳምንነበር
# የዛሬዘመንሰውግንበዓይኑካላየ
# በእጁካልዳሰሰበንግግርብቻአያምንም
# እኔምበወሬየሰማሁትንሳይሆንበዓይኔያየሁትንብነግርህእኔየነገርኩህንበቃልምሆነበጽሕፈትብታወራውተቀባይላታገኝምንአታከተህ
# እንደዚህያለየተጠራጣሪናየተመራማሪዘመንይመጣልብሎየገመተየለምእንጂ
# በየዋህነትከመመራትመጠራጠርቢኖርኖሮ
# የላሊበላታሪካዊሕንፃሥራዛሬለሚያየውሁሉእያጠራጠረራስምታትየሆነውንራሱቅዱስላሊበላእንደምንአድርጎእንደሠራውበዘመኑየነበሩትሰዎችአብራርተውይጽፉትነበር
# ታሪክፀሐፊእውነትንእንጂከእውነትየራቀያልሆነውንእንደሆነአድርጎአጋኖቢጽፈውምየሰውንየመመራመርአስተያየትወደጥርጣሬከመምራትበቀርተቀባይነትአያገኝም
# ታሪክበአጻጻፍላይቁልምጫየማይፈልግሥራንናአሠራርንብቻየሚያስተዋውቅዘለዓለማዊመታሰቢያስለሆነሐቀኛሰውይፈልጋል
# ቤተሰቦቹን/ቤተሰቦቿን
# የኅብረተሰቡ/የቤተሰብ
# መቀፋቀፊያሽብርተኝነት
# የኮንፈረንሱ/የሴሚናሩና
# ተቆርጦለታልሥልጣናቸውን
# ግብዓቶችአሠራርከስምንት
# አድንቀንባይሆንልንጨለማውን
# ተጎናጽፋትንጎራደዳለች
# እንደተጻፈ/እንደተተረጐመ
# ተፈራመንደርደሪያይህንን
# እንደምናስተካክላቸውና
# የአትክልት/የሱፍ/ኦሊቭ/
# ጣይቱፀሐይቱደማቂቱጣይቱ
# ኮከብ5ኢንተርኮንቲኔንታል
# ሚኒስትርእንደሚያውቁት
# ተሸናፊነትበአብዛኛዎቹ
# ይገባቸዋል/አይገባቸውም
# የሴሞችን/የሰሜነኞችን
# አልተገለጸምበሽብርተኝነት
# ሐሐሐሀሐሀሀሀሀበበበሀበሻ
# አልተሟላምለመንግሥትም
# እንደየአስፈላጊነታቸውም
# እንደሚያሽመደምዱዋቸው
# የሚያከብር/የሚያስተናግድ
# አክራሪነት/ፅንፈኝነት
# በወ/መ/ሥ/ሥ/ሕ/ቁ/122
# ፍራንሴዝኮንሰርትዝግጅት
# ቅ11/12870/1/09
# /03/14/679/712665/
# በፋርማኮኢምፒዲዮሞሎጂ
# ሳያንበረክከንጨለምተኛ
# የሚያቀርብ/የምታቀርብ
# ዘገባዎችን/ፕሮግራሞችን
# የኢንዱስትሪያላይዜሽን
# የሚለውጥሰኔሸርጣንግድብ
# ይንበረከካልአንፃራዊም
# ምጣኔ20022003200420051መቀሌ21
# መለያየትየፓትርያርኩን
# ያልተዘረዘረ/ያልተገለጸ
# ገብረዮሐንስከእያንዳንዱ
# የሚደፍሩት/የሚፈቅዱበት
# አገልግሎትበኤሌክትሪክ
# አልነበረምየኤሌክትሪክ
# ቲሲ4ሲቲ21ቲቲ72ቲቲ0ጂጂ170
# ዘካቶሊካውያንየኢትዮጵያ
# ስለዴሞክራሲያዊነታቸው
# እኛምእንመጣለንአረበረከቴ
# የሚያስጠይቅ/የሚያስቀጣ
# ዕቃዎችአዘገጃጀትደብረወርቅ
# ያቀረባቸው/የሚያቀርባቸው
# ለማለዘዝ/ለመቀልበስና
# ለኢንዱስትሪያላይዜሽን
# ዕቃዎችአዘገጃጀትቲማቲም
# እንደሚያስሰውፍቅርሽን
# ተደርጎላቸዋልበአፍሪካ

# %%
# sample = np.random.choice(am_vocab_size, (120, 10), replace=False)
# reverse_vocab = dict(zip(am_vocab.values(), am_vocab.keys()))
# words = ''
# for j in range(sample.shape[0]):
#     row = sample[j]
#     for i in row:
#         words += reverse_vocab[i] + ' '
#     words += '\n\n'
#     if j % 6 == 0:
#         name = 'wordset/words-{0}.txt'.format(j)
#         open(name, 'w', encoding='utf-8').write(words)
#         words = ' '
